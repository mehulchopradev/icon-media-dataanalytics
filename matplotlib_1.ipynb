# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
year = [2015, 2016, 2017, 2018, 2019, 2020]
revenue = [2500000, 2900000, 3500000, 3200000, 3000000, 4600000]
revenue_2 = [2700000, 3000000, 3200000, 3800000, 2500000, 4700000]

# %%
plt.plot(year, revenue, color='red', linestyle='dashed', marker='o')
plt.plot(year, revenue_2, color='blue', linestyle='dashed', marker='o')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.title('Last 6 years revenue')
plt.grid()
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.plot(year, revenue, color='red', linestyle='dashed', marker='o')
plt.title('Last 6 years revenue')
plt.ylabel('Revenue')

plt.subplot(2, 1, 2)
plt.plot(year, revenue_2, color='blue', linestyle='dashed', marker='o')

plt.xlabel('Year')
plt.ylabel('Revenue')
plt.show()

# %%
# heights of students in a college is a normal distribution
heights = np.random.normal(163, 20, 1000)
heights
# Out:
# array([147.60477194, 113.28152145, 202.16709833, 161.89618433,
#        149.93724344, 157.07566657, 169.19714647, 164.3197969 ,
#        135.85219623, 187.56782016, 190.73231229, 153.04450841,
#        147.81074662, 169.42917042, 174.36078927, 166.08821985,
#        148.8714538 , 149.91601487, 136.27914106, 161.63125578,
#        137.56888519, 165.72813414, 163.59324276, 145.77717599,
#        169.95527027, 127.23519959, 153.9343083 , 169.43771987,
#        171.79549354, 135.7941228 , 173.40073352, 195.32982887,
#        161.75507977, 147.66532377, 151.17724963, 164.06149153,
#        163.38661471, 163.18757232, 169.26963455, 162.49298784,
#        161.17896519, 158.68033686, 156.29810267, 163.37754181,
#        186.97522741, 153.49862567, 150.02783422, 163.17091784,
#        198.65348917, 164.4116638 , 164.55052584, 126.93442627,
#        199.44701611, 170.57142976, 177.6333208 , 189.54330733,
#        173.5385812 , 199.66507512, 133.70246173, 158.14327005,
# ...

# %%
plt.hist(heights)
plt.show()

# %%
companies = ['Apple', 'Google', 'Microsoft']
market_share = [45, 50, 5]

plt.pie(market_share, labels=companies)
plt.show()
