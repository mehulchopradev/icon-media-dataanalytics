# %%
import pandas as pd

# %%
path = 'data/temperaturesbarcelonadesde1780.csv'
d1 = pd.read_csv(path)
d1
# Out:
#       Any  Temp_Mitjana_Gener  Temp_Mitjana_Febrer  Temp_Mitjana_Marc  \
# 0    1780                 6.7                  7.3               11.6
# 1    1781                 7.5                  8.9               10.9
# 2    1782                 8.2                  6.1                9.8
# 3    1783                 8.3                  8.6                9.6
# 4    1784                 7.3                  7.1               10.8
# ..    ...                 ...                  ...                ...
# 236  2016                10.7                 11.3               11.1
# 237  2017                 7.9                 11.4               13.3
# 238  2018                10.5                  6.7               10.8
# 239  2019                 8.1                 11.9               13.5
# 240  2020                10.0                 12.8               11.9
#
#      Temp_Mitjana_Abril  Temp_Mitjana_Maig  Temp_Mitjana_Juny  \
# 0                  11.4               16.3               19.1
# ...

# %%
d1.set_index('Any', inplace=True)
d1.index.name = 'Year'

# %%
d1
# Out:
#       Temp_Mitjana_Gener  Temp_Mitjana_Febrer  Temp_Mitjana_Marc  \
# Year
# 1780                 6.7                  7.3               11.6
# 1781                 7.5                  8.9               10.9
# 1782                 8.2                  6.1                9.8
# 1783                 8.3                  8.6                9.6
# 1784                 7.3                  7.1               10.8
# ...                  ...                  ...                ...
# 2016                10.7                 11.3               11.1
# 2017                 7.9                 11.4               13.3
# 2018                10.5                  6.7               10.8
# 2019                 8.1                 11.9               13.5
# 2020                10.0                 12.8               11.9
#
#       Temp_Mitjana_Abril  Temp_Mitjana_Maig  Temp_Mitjana_Juny  \
# Year
# 1780                11.4               16.3               19.1
# ...

# %%
d1['yearly_avg'] = d1.mean(axis=1)
d1
# Out:
#       Temp_Mitjana_Gener  Temp_Mitjana_Febrer  Temp_Mitjana_Marc  \
# Year
# 1780                 6.7                  7.3               11.6
# 1781                 7.5                  8.9               10.9
# 1782                 8.2                  6.1                9.8
# 1783                 8.3                  8.6                9.6
# 1784                 7.3                  7.1               10.8
# ...                  ...                  ...                ...
# 2016                10.7                 11.3               11.1
# 2017                 7.9                 11.4               13.3
# 2018                10.5                  6.7               10.8
# 2019                 8.1                 11.9               13.5
# 2020                10.0                 12.8               11.9
#
#       Temp_Mitjana_Abril  Temp_Mitjana_Maig  Temp_Mitjana_Juny  \
# Year
# 1780                11.4               16.3               19.1
# ...

# %%
d2 = d1[['yearly_avg']]
d2
# Out:
#       yearly_avg
# Year
# 1780   14.075000
# 1781   14.716667
# 1782   13.633333
# 1783   14.400000
# 1784   13.616667
# ...          ...
# 2016   16.475000
# 2017   16.375000
# 2018   16.283333
# 2019   16.525000
# 2020   16.758333
#
# [241 rows x 1 columns]

# %%
d2.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# rolling averages ( rolling mean, rolling window)

# %%
# Simple moving average

# %%
d2['rolling_3'] = d2.yearly_avg.rolling(3, min_periods=1).mean()
d2
# Out:
# <ipython-input-16-ab67ad9bdae2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['rolling_3'] = d2.yearly_avg.rolling(3, min_periods=1).mean()
#       yearly_avg  rolling_3
# Year
# 1780   14.075000  14.075000
# 1781   14.716667  14.395833
# 1782   13.633333  14.141667
# 1783   14.400000  14.250000
# 1784   13.616667  13.883333
# ...          ...        ...
# 2016   16.475000  16.450000
# 2017   16.375000  16.483333
# 2018   16.283333  16.377778
# 2019   16.525000  16.394444
# 2020   16.758333  16.522222
#
# [241 rows x 2 columns]

# %%
d2['rolling_10'] = d2.yearly_avg.rolling(10, min_periods=1).mean()
d2
# Out:
# <ipython-input-18-7388cee1a237>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['rolling_10'] = d2.yearly_avg.rolling(10, min_periods=1).mean()
#       yearly_avg  rolling_3  rolling_10
# Year
# 1780   14.075000  14.075000   14.075000
# 1781   14.716667  14.395833   14.395833
# 1782   13.633333  14.141667   14.141667
# 1783   14.400000  14.250000   14.206250
# 1784   13.616667  13.883333   14.088333
# ...          ...        ...         ...
# 2016   16.475000  16.450000   16.011667
# 2017   16.375000  16.483333   16.054167
# 2018   16.283333  16.377778   16.139167
# 2019   16.525000  16.394444   16.170000
# 2020   16.758333  16.522222   16.340833
#
# [241 rows x 3 columns]

# %%
d2['rolling_20'] = d2.yearly_avg.rolling(20, min_periods=1).mean()
d2
# Out:
# <ipython-input-20-fc0416cbaaac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['rolling_20'] = d2.yearly_avg.rolling(20, min_periods=1).mean()
#       yearly_avg  rolling_3  rolling_10  rolling_20
# Year
# 1780   14.075000  14.075000   14.075000   14.075000
# 1781   14.716667  14.395833   14.395833   14.395833
# 1782   13.633333  14.141667   14.141667   14.141667
# 1783   14.400000  14.250000   14.206250   14.206250
# 1784   13.616667  13.883333   14.088333   14.088333
# ...          ...        ...         ...         ...
# 2016   16.475000  16.450000   16.011667   15.974167
# 2017   16.375000  16.483333   16.054167   15.978333
# 2018   16.283333  16.377778   16.139167   16.011667
# ...

# %%
d2[['rolling_20']].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
d2.plot()
# Out:
# <AxesSubplot:xlabel='Year'>
